# %% [markdown]
# <a href="https://colab.research.google.com/github/proppy/tinytapeout-xls-test/blob/main/notebooks/popcount.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TinyTapeOut XLS flow
#
# ```
# Copyright 2022 Google LLC.
# SPDX-License-Identifier: Apache-2.0
# ```
#
# Run the [TinyTapeOut](https://tinytapeout.com) flow for designs using [XLS: Accelerated HW Synthesis](https://github.com/google/xls) toolkit.

# %%
#@title Configure WOWKI ID

WOKWI_PROJECT_ID = 339800239192932947 #@param {type:"integer"}

# %% [markdown]
# ## Install dependencies

# %%
import os
import pathlib
import sys

# !curl -Ls https://micro.mamba.pm/api/micromamba/linux-64/latest | tar -xvj bin/micromamba
conda_prefix_path = pathlib.Path('conda-env')
site_package_path = conda_prefix_path / 'lib/python3.7/site-packages'
sys.path.append(str(site_package_path.resolve()))
CONDA_PREFIX = str(conda_prefix_path.resolve())
PATH = os.environ['PATH']
LD_LIBRARY_PATH = os.environ.get('LD_LIBRARY_PATH', '')
# %env CONDA_PREFIX={CONDA_PREFIX}
# %env PATH={CONDA_PREFIX}/bin:{PATH}
# %env LD_LIBRARY_PATH={CONDA_PREFIX}/lib:{LD_LIBRARY_PATH}
# !bin/micromamba create --yes --prefix $CONDA_PREFIX
# !echo 'python ==3.7*' >> {CONDA_PREFIX}/conda-meta/pinned
# !bin/micromamba install --yes --prefix $CONDA_PREFIX \
                        --channel litex-hub \
                        --channel main \
                        open_pdks.sky130a \
                        magic \
                        openroad \
                        netgen \
                        yosys \
                        xls
# !bin/micromamba install --yes --prefix $CONDA_PREFIX \
                        --channel conda-forge \
                        tcllib gdstk pyyaml click
# Out:
# bin/micromamba
# env: CONDA_PREFIX=/content/conda-env
# env: PATH=/content/conda-env/bin:/content/conda-env/bin:/content/conda-env/bin:/content/conda-env/bin:/opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts
# env: LD_LIBRARY_PATH=/content/conda-env/lib:/content/conda-env/lib:/content/conda-env/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
#
#                                            __
#           __  ______ ___  ____ _____ ___  / /_  ____ _
#          / / / / __ `__ \/ __ `/ __ `__ \/ __ \/ __ `/
#         / /_/ / / / / / / /_/ / / / / / / /_/ / /_/ /
#        / .___/_/ /_/ /_/\__,_/_/ /_/ /_/_.___/\__,_/
#       /_/
#
# Empty environment created at prefix: /content/conda-env
#
#                                            __
#           __  ______ ___  ____ _____ ___  / /_  ____ _
#          / / / / __ `__ \/ __ `/ __ `__ \/ __ \/ __ `/
#         / /_/ / / / / / / /_/ / / / / / / /_/ / /_/ /
#        / .___/_/ /_/ /_/\__,_/_/ /_/ /_/_.___/\__,_/
#       /_/
#
# [+] 0.0s
# litex-hub/linux-64  ⣾
# litex-hub/noarch    ⣾
# main/linux-64       ⣾
# main/noarch         ⣾  [+] 0.1s
# litex-hub/linux-64  ⣾
# litex-hub/noarch    ⣾
# main/linux-64       ⣾
# main/noarch         ⣾  [+] 0.2s
# litex-hub/linux-64  ⣾
# litex-hub/noarch    ⣾
# main/linux-64       ⣾
# main/noarch         ⣾  main/noarch                                                   No change
# litex-hub/noarch                                              No change
# [+] 0.3s
# litex-hub/linux-64  ⣾
# main/linux-64       ⣾  [+] 0.4s
# litex-hub/linux-64  ⣾
# main/linux-64       ⣾  main/linux-64                                                 No change
# litex-hub/linux-64                                            No change
# warning  libmamba linux version not found (virtual package skipped)
#
# Pinned packages:
#   - python 3.7*
#
#
# Transaction
#
#   Prefix: /content/conda-env
#
#   Updating specs:
#
#    - open_pdks.sky130a
#    - magic
#    - openroad
#    - netgen
#    - yosys
#    - xls
#
#
#   Package                          Version  Build                 Channel                  Size
# ─────────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ─────────────────────────────────────────────────────────────────────────────────────────────────
#
#   + _libgcc_mutex                      0.1  main                  main/linux-64          Cached
#   + _openmp_mutex                      5.1  1_gnu                 main/linux-64          Cached
#   + bzip2                            1.0.8  h7b6447c_0            main/linux-64          Cached
#   + ca-certificates             2022.07.19  h06a4308_0            main/linux-64          Cached
#   + cairo                           1.16.0  h19f5f5c_2            main/linux-64          Cached
#   + certifi                      2022.6.15  py37h06a4308_0        main/linux-64          Cached
#   + fontconfig                      2.13.1  h6c09931_0            main/linux-64          Cached
#   + freetype                        2.11.0  h70c0345_0            main/linux-64          Cached
#   + glib                            2.69.1  h4ff587b_1            main/linux-64          Cached
#   + icu                               58.2  he6710b0_3            main/linux-64          Cached
#   + ld_impl_linux-64                  2.38  h1181459_1            main/linux-64          Cached
#   + libboost                        1.73.0  h28710b8_12           main/linux-64          Cached
#   + libffi                             3.3  he6710b0_2            main/linux-64          Cached
#   + libgcc-ng                       11.2.0  h1234567_1            main/linux-64          Cached
#   + libgomp                         11.2.0  h1234567_1            main/linux-64          Cached
#   + libpng                          1.6.37  hbc83047_0            main/linux-64          Cached
#   + libstdcxx-ng                    11.2.0  h1234567_1            main/linux-64          Cached
#   + libuuid                          1.0.3  h7f8727e_2            main/linux-64          Cached
#   + libxcb                            1.15  h7f8727e_0            main/linux-64          Cached
#   + libxml2                         2.9.14  h74e7548_0            main/linux-64          Cached
#   + lz4-c                            1.9.3  h295c915_1            main/linux-64          Cached
#   + magic               8.3.315_0_gf7df5e7  20220819_174700       litex-hub/linux-64     Cached
#   + ncurses                            6.3  h5eee18b_3            main/linux-64          Cached
#   + netgen              1.5.227_0_g7e9bd9f  20220819_174700       litex-hub/linux-64     Cached
#   + open_pdks.sky130a   1.0.323_0_g6003ab3  20220819_174700       litex-hub/noarch       Cached
#   + openroad           2.0_4752_g8ff388d1b  20220819_174700       litex-hub/linux-64     Cached
#   + openssl                         1.1.1q  h7f8727e_0            main/linux-64          Cached
#   + pcre                              8.45  h295c915_0            main/linux-64          Cached
#   + pip                             22.1.2  py37h06a4308_0        main/linux-64          Cached
#   + pixman                          0.40.0  h7f8727e_1            main/linux-64          Cached
#   + python                          3.7.13  h12debd9_0            main/linux-64          Cached
#   + readline                         8.1.2  h7f8727e_1            main/linux-64          Cached
#   + setuptools                      63.4.1  py37h06a4308_0        main/linux-64          Cached
#   + sqlite                          3.39.2  h5082296_0            main/linux-64          Cached
#   + tk                              8.6.12  h1ccaba5_0            main/linux-64          Cached
#   + wheel                           0.37.1  pyhd3eb1b0_0          main/noarch            Cached
#   + xls                 0.0_2517_g16b6055a  20220819_174700       litex-hub/linux-64     Cached
#   + xz                               5.2.5  h7f8727e_1            main/linux-64          Cached
#   + yosys               0.20_46_g029c2785e  20220819_174700_py37  litex-hub/linux-64     Cached
#   + zlib                            1.2.12  h7f8727e_2            main/linux-64          Cached
#   + zstd                             1.5.2  ha4553b6_0            main/linux-64          Cached
#
#   Summary:
#
#   Install: 41 packages
#
#   Total download: 0 B
#
# ─────────────────────────────────────────────────────────────────────────────────────────────────
#
#
# Transaction starting
# Linking open_pdks.sky130a-1.0.323_0_g6003ab3-20220819_174700
# Linking _libgcc_mutex-0.1-main
# Linking libstdcxx-ng-11.2.0-h1234567_1
# Linking ld_impl_linux-64-2.38-h1181459_1
# Linking ca-certificates-2022.07.19-h06a4308_0
# Linking libgomp-11.2.0-h1234567_1
# Linking _openmp_mutex-5.1-1_gnu
# Linking libgcc-ng-11.2.0-h1234567_1
# Linking libuuid-1.0.3-h7f8727e_2
# Linking pixman-0.40.0-h7f8727e_1
# Linking pcre-8.45-h295c915_0
# Linking icu-58.2-he6710b0_3
# Linking lz4-c-1.9.3-h295c915_1
# Linking xz-5.2.5-h7f8727e_1
# Linking openssl-1.1.1q-h7f8727e_0
# Linking libxcb-1.15-h7f8727e_0
# Linking libffi-3.3-he6710b0_2
# Linking bzip2-1.0.8-h7b6447c_0
# Linking ncurses-6.3-h5eee18b_3
# Linking zlib-1.2.12-h7f8727e_2
# Linking readline-8.1.2-h7f8727e_1
# Linking glib-2.69.1-h4ff587b_1
# Linking libxml2-2.9.14-h74e7548_0
# Linking libpng-1.6.37-hbc83047_0
# Linking zstd-1.5.2-ha4553b6_0
# Linking tk-8.6.12-h1ccaba5_0
# Linking sqlite-3.39.2-h5082296_0
# Linking freetype-2.11.0-h70c0345_0
# Linking libboost-1.73.0-h28710b8_12
# Linking python-3.7.13-h12debd9_0
# Linking fontconfig-2.13.1-h6c09931_0
# Linking certifi-2022.6.15-py37h06a4308_0
# Linking cairo-1.16.0-h19f5f5c_2
# Linking setuptools-63.4.1-py37h06a4308_0
# Linking xls-0.0_2517_g16b6055a-20220819_174700
# Linking magic-8.3.315_0_gf7df5e7-20220819_174700
# Linking wheel-0.37.1-pyhd3eb1b0_0
# Linking pip-22.1.2-py37h06a4308_0
# Linking yosys-0.20_46_g029c2785e-20220819_174700_py37
# Linking netgen-1.5.227_0_g7e9bd9f-20220819_174700
# Linking openroad-2.0_4752_g8ff388d1b-20220819_174700
# Transaction finished
#
#                                            __
#           __  ______ ___  ____ _____ ___  / /_  ____ _
#          / / / / __ `__ \/ __ `/ __ `__ \/ __ \/ __ `/
#         / /_/ / / / / / / /_/ / / / / / / /_/ / /_/ /
#        / .___/_/ /_/ /_/\__,_/_/ /_/ /_/_.___/\__,_/
#       /_/
#
# [+] 0.0s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.2s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  conda-forge/noarch                                            No change
# [+] 0.3s
# conda-forge/linux-64  ⣾  [+] 0.4s
# conda-forge/linux-64  ⣾  [+] 0.5s
# conda-forge/linux-64  ⣾  [+] 0.6s
# conda-forge/linux-64  ⣾  [+] 0.7s
# conda-forge/linux-64  ⣾  [+] 0.8s
# conda-forge/linux-64  ⣾  [+] 0.9s
# conda-forge/linux-64  ⣾  [+] 1.0s
# conda-forge/linux-64  ⣾  [+] 1.1s
# conda-forge/linux-64  ⣾  [+] 1.2s
# conda-forge/linux-64  ⣾  [+] 1.3s
# conda-forge/linux-64  ⣾  [+] 1.4s
# conda-forge/linux-64  ⣾  [+] 1.5s
# conda-forge/linux-64  ⣾  [+] 1.6s
# conda-forge/linux-64  ⣾  [+] 1.7s
# conda-forge/linux-64  ⣾  [+] 1.8s
# conda-forge/linux-64  ⣾  [+] 1.9s
# conda-forge/linux-64  ⣾  [+] 2.0s
# conda-forge/linux-64  ⣾  [+] 2.1s
# conda-forge/linux-64  ⣾  [+] 2.2s
# conda-forge/linux-64  ⣾  [+] 2.3s
# conda-forge/linux-64  ⣾  [+] 2.4s
# conda-forge/linux-64  ⣾  [+] 2.5s
# conda-forge/linux-64  ⣾  [+] 2.6s
# conda-forge/linux-64  ⣾  [+] 2.7s
# conda-forge/linux-64  ⣾  [+] 2.8s
# conda-forge/linux-64  ⣾  [+] 2.9s
# conda-forge/linux-64  ⣾  [+] 3.0s
# conda-forge/linux-64  ⣾  [+] 3.1s
# conda-forge/linux-64  ⣾  [+] 3.2s
# conda-forge/linux-64  ⣾  [+] 3.3s
# conda-forge/linux-64  ⣾  [+] 3.4s
# conda-forge/linux-64  ⣾  [+] 3.5s
# conda-forge/linux-64  ⣾  [+] 3.6s
# conda-forge/linux-64  ⣾  [+] 3.7s
# conda-forge/linux-64  ⣾  [+] 3.8s
# conda-forge/linux-64  ⣾  [+] 3.9s
# conda-forge/linux-64  ⣾  [+] 4.0s
# conda-forge/linux-64  ⣾  [+] 4.1s
# conda-forge/linux-64  ⣾  [+] 4.2s
# conda-forge/linux-64  ⣾  [+] 4.3s
# conda-forge/linux-64  ⣾  [+] 4.4s
# conda-forge/linux-64  ⣾  [+] 4.5s
# conda-forge/linux-64  ⣾  [+] 4.6s
# conda-forge/linux-64  ⣾  [+] 4.7s
# conda-forge/linux-64  ⣾  [+] 4.8s
# conda-forge/linux-64  ⣾  [+] 4.9s
# conda-forge/linux-64  ⣾  [+] 5.0s
# conda-forge/linux-64  ⣾  [+] 5.1s
# conda-forge/linux-64  ⣾  [+] 5.2s
# conda-forge/linux-64  ⣾  [+] 5.3s
# conda-forge/linux-64  ⣾  [+] 5.4s
# conda-forge/linux-64  ⣾  [+] 5.5s
# conda-forge/linux-64  ⣾  [+] 5.6s
# conda-forge/linux-64  ⣾  [+] 5.7s
# conda-forge/linux-64  ⣾  [+] 5.8s
# conda-forge/linux-64  ⣾  [+] 5.9s
# conda-forge/linux-64  ⣾  [+] 6.0s
# conda-forge/linux-64  ⣾  [+] 6.1s
# conda-forge/linux-64  ⣾  [+] 6.2s
# conda-forge/linux-64  ⣾  [+] 6.3s
# conda-forge/linux-64  ⣾  [+] 6.4s
# conda-forge/linux-64  ⣾  [+] 6.5s
# conda-forge/linux-64  ⣾  [+] 6.6s
# conda-forge/linux-64  ⣾  [+] 6.7s
# conda-forge/linux-64  ⣾  [+] 6.8s
# conda-forge/linux-64  ⣾  [+] 6.9s
# conda-forge/linux-64  ⣾  [+] 7.0s
# conda-forge/linux-64 100%[+] 7.1s
# conda-forge/linux-64 100%[+] 7.2s
# conda-forge/linux-64 100%[+] 7.3s
# conda-forge/linux-64 100%[+] 7.4s
# conda-forge/linux-64 100%[+] 7.5s
# conda-forge/linux-64 100%[+] 7.6s
# conda-forge/linux-64 100%[+] 7.7s
# conda-forge/linux-64
# warning  libmamba linux version not found (virtual package skipped)
#
# Pinned packages:
#   - python 3.7*
#   - python 3.7.*
#
#
# Transaction
#
#   Prefix: /content/conda-env
#
#   Updating specs:
#
#    - tcllib
#    - gdstk
#    - pyyaml
#    - click
#
#
#   Package               Version  Build                Channel                    Size
# ───────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────────────────────────────
#
#   + click                 8.1.3  py37h89c1867_0       conda-forge/linux-64     Cached
#   + gdstk                 0.7.0  py37h60116be_0       conda-forge/linux-64     Cached
#   + importlib-metadata   4.11.4  py37h89c1867_0       conda-forge/linux-64     Cached
#   + libblas               3.9.0  15_linux64_openblas  conda-forge/linux-64     Cached
#   + libcblas              3.9.0  15_linux64_openblas  conda-forge/linux-64     Cached
#   + libgfortran-ng       12.1.0  h69a702a_16          conda-forge/linux-64     Cached
#   + libgfortran5         12.1.0  hdcd56e2_16          conda-forge/linux-64     Cached
#   + liblapack             3.9.0  15_linux64_openblas  conda-forge/linux-64     Cached
#   + libopenblas          0.3.20  pthreads_h78a6416_0  conda-forge/linux-64     Cached
#   + numpy                1.21.6  py37h976b520_0       conda-forge/linux-64     Cached
#   + python_abi              3.7  2_cp37m              conda-forge/linux-64     Cached
#   + pyyaml                  6.0  py37h540881e_4       conda-forge/linux-64     Cached
#   + tcllib                 1.20  hba23847_0           conda-forge/linux-64     Cached
#   + typing_extensions     4.3.0  pyha770c72_0         conda-forge/noarch       Cached
#   + yaml                  0.2.5  h7f98852_2           conda-forge/linux-64     Cached
#   + zipp                  3.8.1  pyhd8ed1ab_0         conda-forge/noarch       Cached
#
#   Summary:
#
#   Install: 16 packages
#
#   Total download: 0 B
#
# ───────────────────────────────────────────────────────────────────────────────────────
#
#
# Transaction starting
# Linking tcllib-1.20-hba23847_0
# Linking python_abi-3.7-2_cp37m
# Linking yaml-0.2.5-h7f98852_2
# Linking libgfortran5-12.1.0-hdcd56e2_16
# Linking pyyaml-6.0-py37h540881e_4
# Linking libgfortran-ng-12.1.0-h69a702a_16
# Linking libopenblas-0.3.20-pthreads_h78a6416_0
# Linking libblas-3.9.0-15_linux64_openblas
# Linking libcblas-3.9.0-15_linux64_openblas
# Linking liblapack-3.9.0-15_linux64_openblas
# Linking numpy-1.21.6-py37h976b520_0
# Linking gdstk-0.7.0-py37h60116be_0
# Linking typing_extensions-4.3.0-pyha770c72_0
# Linking zipp-3.8.1-pyhd8ed1ab_0
# Linking importlib-metadata-4.11.4-py37h89c1867_0
# Linking click-8.1.3-py37h89c1867_0
# Transaction finished

# %% [markdown]
# ## Get TinyTapeout XLS template

# %%
# !rm -fr tinytapeout-xls-test
# !git clone https://github.com/proppy/tinytapeout-xls-test.git
# Out:
# Cloning into 'tinytapeout-xls-test'...
# remote: Enumerating objects: 89, done.
# remote: Counting objects: 100% (89/89), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 89 (delta 39), reused 10 (delta 0), pack-reused 0
# Unpacking objects: 100% (89/89), done.

# %% [markdown]
# ## Update DSLX module

# %%
# %%bash -c 'cat > tinytapeout-xls-test/src/user_module.x; interpreter_main tinytapeout-xls-test/src/user_module.x'
#
# fn popcount(n: u8) -> u8 {
#   for (i, c): (u8, u8) in u8:0..u8:8 {
#     c + ((n >> i) & u8:1)
#   }(u8:0)
# }
#
# #![test]
# fn popcount_test() {
#   let _= assert_eq(popcount(u8:0b0000_0000), u8:0);
#   let _= assert_eq(popcount(u8:0b0000_0001), u8:1);
#   let _= assert_eq(popcount(u8:0b1111_0000), u8:4);
#   let _= assert_eq(popcount(u8:0b0101_0101), u8:4);
#   let _= assert_eq(popcount(u8:0b1111_1111), u8:8);
#   _
# }
#
# pub fn user_module(io_in: u8) -> u8 {
#   popcount(io_in)
# }
# Out:
# [ RUN UNITTEST  ] popcount_test
# [            OK ]
# [===============] 1 test(s) ran; 0 failed; 0 skipped.

# %% [markdown]
# ## Generate verilog

# %%
# !make -C tinytapeout-xls-test generate
# !make -C tinytapeout-xls-test WOKWI_PROJECT_ID={WOKWI_PROJECT_ID} fetch
# !cat tinytapeout-xls-test/src/user_module_{WOKWI_PROJECT_ID}.v
# Out:
# make: Entering directory '/content/tinytapeout-xls-test'
# ir_converter_main --top=user_module src/user_module.x > src/user_module.ir
# opt_main src/user_module.ir > src/user_module_opt.ir
# codegen_main --module_name user_module_USER_MODULE_ID --use_system_verilog=false --generator=combinational src/user_module_opt.ir > src/user_module.v
# make: Leaving directory '/content/tinytapeout-xls-test'
# make: Entering directory '/content/tinytapeout-xls-test'
# sed -e 's/USER_MODULE_ID/339800239192932947/g' src/user_module.v > src/user_module_339800239192932947.v
# sed -e 's/USER_MODULE_ID/339800239192932947/g' template/scan_wrapper.v > src/scan_wrapper_339800239192932947.v
# sed -e 's/USER_MODULE_ID/339800239192932947/g' template/config.tcl > src/config.tcl
# echo 339800239192932947 > src/ID
# make: Leaving directory '/content/tinytapeout-xls-test'
# module user_module_339800239192932947(
#   input wire [7:0] io_in,
#   output wire [7:0] out
# );
#   wire [1:0] add_347;
#   wire [1:0] add_349;
#   wire [1:0] add_351;
#   wire [1:0] add_353;
#   wire [2:0] add_359;
#   wire [2:0] add_361;
#   wire [3:0] add_365;
#   assign add_347 = {1'h0, io_in[0]} + {1'h0, io_in[1]};
#   assign add_349 = {1'h0, io_in[2]} + {1'h0, io_in[3]};
#   assign add_351 = {1'h0, io_in[4]} + {1'h0, io_in[5]};
#   assign add_353 = {1'h0, io_in[6]} + {1'h0, io_in[7]};
#   assign add_359 = {1'h0, add_347} + {1'h0, add_349};
#   assign add_361 = {1'h0, add_351} + {1'h0, add_353};
#   assign add_365 = {1'h0, add_359} + {1'h0, add_361};
#   assign out = {4'h0, add_365};
# endmodule

# %% [markdown]
# ## Get OpenLane

# %%
# !git clone --depth=1 https://github.com/The-OpenROAD-Project/OpenLane
# Out:
# fatal: destination path 'OpenLane' already exists and is not an empty directory.

# %% [markdown]
# ## Run OpenLane Flow

# %%
import os
import pathlib
OPENLANE_ROOT=str(pathlib.Path('OpenLane').resolve())
PATH=os.environ['PATH']
# %env PDK_ROOT={CONDA_PREFIX}/share/pdk
# %env PDK=sky130A
# %env STD_CELL_LIBRARY=sky130_fd_sc_hd
# %env STD_CELL_LIBRARY_OPT=sky130_fd_sc_hd
# %env TCLLIBPATH={CONDA_PREFIX}/lib/tcllib1.20
# %env OPENLANE_ROOT={OPENLANE_ROOT}
# %env PATH={PATH}:{OPENLANE_ROOT}:{OPENLANE_ROOT}/scripts
# %env OPENLANE_LOCAL_INSTALL=1
# %env OPENLANE_OVERRIDE_ENV=TEST_MISMATCHES=none,RUN_KLAYOUT=0,RUN_CVC=0
# !make -C tinytapeout-xls-test HARDEN_ENV=native harden
# Out:
# env: PDK_ROOT=/content/conda-env/share/pdk
# env: PDK=sky130A
# env: STD_CELL_LIBRARY=sky130_fd_sc_hd
# env: STD_CELL_LIBRARY_OPT=sky130_fd_sc_hd
# env: TCLLIBPATH=/content/conda-env/lib/tcllib1.20
# env: OPENLANE_ROOT=/content/OpenLane
# env: PATH=/content/conda-env/bin:/content/conda-env/bin:/content/conda-env/bin:/content/conda-env/bin:/opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts:/content/OpenLane:/content/OpenLane/scripts
# env: OPENLANE_LOCAL_INSTALL=1
# env: OPENLANE_OVERRIDE_ENV=TEST_MISMATCHES=none,RUN_KLAYOUT=0,RUN_CVC=0
# make: Entering directory '/content/tinytapeout-xls-test'
# /content/OpenLane/flow.tcl -override_env TEST_MISMATCHES=none,RUN_KLAYOUT=0,RUN_CVC=0 -design src/
# OpenLane e14b1fd8c29643465e35ad4c3a16349d96bdaa21
# All rights reserved. (c) 2020-2022 Efabless Corporation and contributors.
# Available under the Apache License, version 2.0. See the LICENSE file for more details.
#
# [INFO]: Using configuration in 'src/config.tcl'...
# [INFO]: PDK Root: /content/conda-env/share/pdk
# [INFO]: Process Design Kit: sky130A
# [INFO]: Standard Cell Library: sky130_fd_sc_hd
# [INFO]: Optimization Standard Cell Library: sky130_fd_sc_hd
# [WARNING]: GLB_RT_LAYER_ADJUSTMENTS is now deprecated; use GRT_LAYER_ADJUSTMENTS instead.
# [INFO]: Run Directory: /content/tinytapeout-xls-test/src/runs/RUN_2022.08.31_04.51.17
# [INFO]: Preparing LEF files for the nom corner...
# [INFO]: Preparing LEF files for the min corner...
# [INFO]: Preparing LEF files for the max corner...
# [STEP 1]
# [INFO]: Running Synthesis (log: src/runs/RUN_2022.08.31_04.51.17/logs/synthesis/1-synthesis.log)...
# [STEP 2]
# [INFO]: Running Single-Corner Static Timing Analysis (log: src/runs/RUN_2022.08.31_04.51.17/logs/synthesis/2-sta.log)...
# [STEP 3]
# [INFO]: Running Initial Floorplanning (log: src/runs/RUN_2022.08.31_04.51.17/logs/floorplan/3-initial_fp.log)...
# [WARNING]: Current core area is too small for a power grid. The power grid will be minimized.
# [INFO]: Extracting core dimensions...
# [INFO]: Set CORE_WIDTH to 88.78, CORE_HEIGHT to 76.16.
# [STEP 4]
# [INFO]: Running IO Placement...
# [STEP 5]
# [INFO]: Running Tap/Decap Insertion (log: src/runs/RUN_2022.08.31_04.51.17/logs/floorplan/5-tap.log)...
# [INFO]: Power planning with power {vccd1} and ground {vssd1}...
# [STEP 6]
# [INFO]: Generating PDN (log: src/runs/RUN_2022.08.31_04.51.17/logs/floorplan/6-pdn.log)...
# [STEP 7]
# [INFO]: Running Global Placement (log: src/runs/RUN_2022.08.31_04.51.17/logs/placement/7-global.log)...
# [STEP 8]
# [INFO]: Running Placement Resizer Design Optimizations (log: src/runs/RUN_2022.08.31_04.51.17/logs/placement/8-resizer.log)...
# [STEP 9]
# [INFO]: Writing Verilog...
# [STEP 10]
# [INFO]: Removing Buffers from Ports (If Applicable) (log: src/runs/RUN_2022.08.31_04.51.17/logs/placement/10-remove_buffers.log)...
# [STEP 11]
# [INFO]: Running Detailed Placement (log: src/runs/RUN_2022.08.31_04.51.17/logs/placement/11-detailed.log)...
# [STEP 12]
# [INFO]: Running Clock Tree Synthesis (log: src/runs/RUN_2022.08.31_04.51.17/logs/cts/12-cts.log)...
# [STEP 13]
# [INFO]: Writing Verilog...
# [STEP 14]
# [INFO]: Running Placement Resizer Timing Optimizations (log: src/runs/RUN_2022.08.31_04.51.17/logs/cts/14-resizer.log)...
# [STEP 15]
# [INFO]: Writing Verilog...
# [STEP 16]
# [INFO]: Removing Buffers from Ports (If Applicable) (log: src/runs/RUN_2022.08.31_04.51.17/logs/placement/16-remove_buffers.log)...
# [INFO]: Routing...
# [STEP 17]
# [INFO]: Running Global Routing Resizer Timing Optimizations (log: src/runs/RUN_2022.08.31_04.51.17/logs/routing/17-resizer.log)...
# [STEP 18]
# [INFO]: Writing Verilog...
# [STEP 19]
# [INFO]: Removing Buffers from Ports (If Applicable) (log: src/runs/RUN_2022.08.31_04.51.17/logs/placement/19-remove_buffers.log)...
# [STEP 20]
# [INFO]: Running Detailed Placement (log: src/runs/RUN_2022.08.31_04.51.17/logs/routing/20-diode_legalization.log)...
# [STEP 21]
# [INFO]: Running Global Routing...
# [INFO]: Starting FastRoute Antenna Repair Iterations...
# [STEP 22]
# [INFO]: Running Fill Insertion (log: src/runs/RUN_2022.08.31_04.51.17/logs/routing/22-fill.log)...
# [STEP 23]
# [INFO]: Writing Verilog...
# [STEP 24]
# [INFO]: Running Detailed Routing (log: src/runs/RUN_2022.08.31_04.51.17/logs/routing/24-detailed.log)...
# [INFO]: No DRC violations after detailed routing.
# [STEP 25]
# [INFO]: Writing Verilog...
# [INFO]: Running parasitics-based static timing analysis...
# [STEP 26]
# [INFO]: Running SPEF Extraction at the min process corner (log: src/runs/RUN_2022.08.31_04.51.17/logs/signoff/26-parasitics_extraction.min.log)...
# [STEP 27]
# [INFO]: Running Multi-Corner Static Timing Analysis at the min process corner (log: src/runs/RUN_2022.08.31_04.51.17/logs/signoff/27-parasitics_multi_corner_sta.min.log)...
# [STEP 28]
# [INFO]: Running SPEF Extraction at the max process corner (log: src/runs/RUN_2022.08.31_04.51.17/logs/signoff/28-parasitics_extraction.max.log)...
# [STEP 29]
# [INFO]: Running Multi-Corner Static Timing Analysis at the max process corner (log: src/runs/RUN_2022.08.31_04.51.17/logs/signoff/29-parasitics_multi_corner_sta.max.log)...
# [STEP 30]
# [INFO]: Running SPEF Extraction at the nom process corner (log: src/runs/RUN_2022.08.31_04.51.17/logs/signoff/30-parasitics_extraction.nom.log)...
# [STEP 31]
# [INFO]: Running Single-Corner Static Timing Analysis at the nom process corner (log: src/runs/RUN_2022.08.31_04.51.17/logs/signoff/31-parasitics_sta.log)...
# [STEP 32]
# [INFO]: Running Multi-Corner Static Timing Analysis at the nom process corner (log: src/runs/RUN_2022.08.31_04.51.17/logs/signoff/32-parasitics_multi_corner_sta.log)...
# [STEP 33]
# [INFO]: Creating IR Drop Report (log: src/runs/RUN_2022.08.31_04.51.17/logs/signoff/33-irdrop.log)...
# [STEP 34]
# [INFO]: Running Magic to generate various views...
# [INFO]: Streaming out GDS-II with Magic (log: src/runs/RUN_2022.08.31_04.51.17/logs/signoff/34-gdsii.log)...
# [INFO]: Generating MAGLEF views...
# [STEP 35]
# [INFO]: Running Magic Spice Export from LEF (log: src/runs/RUN_2022.08.31_04.51.17/logs/signoff/35-spice.log)...
# [STEP 36]
# [INFO]: Writing Powered Verilog (log: ../../dev/null)...
# [STEP 37]
# [INFO]: Writing Verilog...
# [STEP 38]
# [INFO]: Running LEF LVS...
# [STEP 39]
# [INFO]: Running Magic DRC (log: src/runs/RUN_2022.08.31_04.51.17/logs/signoff/39-drc.log)...
# [INFO]: Converting Magic DRC Violations to Magic Readable Format...
# [INFO]: Converting Magic DRC Violations to Klayout XML Database...
# [INFO]: No DRC violations after GDS streaming out.
# [STEP 40]
# [INFO]: Running OpenROAD Antenna Rule Checker (log: src/runs/RUN_2022.08.31_04.51.17/logs/signoff/40-antenna.log)...
# [INFO]: Skipping CVC...
# [INFO]: Saving current set of views in 'src/runs/RUN_2022.08.31_04.51.17/results/final'...
# [INFO]: Saving runtime environment...
# [INFO]: Generating final set of reports...
# [INFO]: Created manufacturability report at 'src/runs/RUN_2022.08.31_04.51.17/reports/manufacturability.rpt'.
# [INFO]: Created metrics report at 'src/runs/RUN_2022.08.31_04.51.17/reports/metrics.csv'.
# [INFO]: There are no max slew, max fanout or max capacitance violations in the design at the typical corner.
# [INFO]: There are no hold violations in the design at the typical corner.
# [INFO]: There are no setup violations in the design at the typical corner.
# [SUCCESS]: Flow complete.
# [INFO]: Note that the following warnings have been generated:
# [WARNING]: Current core area is too small for a power grid. The power grid will be minimized.
#
# make: Leaving directory '/content/tinytapeout-xls-test'

# %% [markdown]
# ## Display layout

# %%
import pathlib
import gdstk
import IPython.display

gdss = sorted(pathlib.Path('runs').glob('*/results/final/gds/*.gds'))
library = gdstk.read_gds(gdss[-1])
top_cells = library.top_level()
top_cells[0].write_svg('user_module.svg')
IPython.display.SVG('user_module.svg')

# %% [markdown]
# ## Dump flow report

# %%
import pandas as pd
import pathlib

pd.options.display.max_rows = None
final_summary_reports = sorted(pathlib.Path('runs').glob('*/reports/metrics.csv'))
df = pd.read_csv(final_summary_reports[-1])
df.transpose()
# Out:
#                                                   0
# design                                     /content
# design_name                                inverter
# config                      RUN_2022.08.31_04.49.15
# flow_status                          flow completed
# total_runtime                            0h0m39s0ms
# routed_runtime                           0h0m18s0ms
# (Cell/mm^2)/Core_Util                          -2.0
# DIEAREA_mm^2                                 0.0025
# CellPer_mm^2                                     -1
# OpenDP_Util                                      -1
# Peak_Memory_Usage_MB                         467.89
# cell_count                                       -1
# tritonRoute_violations                            0
# Short_violations                                  0
# MetSpc_violations                                 0
# OffGrid_violations                                0
# MinHole_violations                                0
# Other_violations                                  0
# Magic_violations                                  0
# antenna_violations                               -1
# lvs_total_errors                                  0
# cvc_total_errors                                 -1
# klayout_violations                               -1
# wire_length                                      86
# vias                                             12
# wns                                             0.0
# pl_wns                                           -1
# optimized_wns                                   0.0
# fastroute_wns                                   0.0
# spef_wns                                         -1
# tns                                             0.0
# pl_tns                                           -1
# optimized_tns                                   0.0
# fastroute_tns                                   0.0
# spef_tns                                         -1
# HPWL                                             -1
# routing_layer1_pct                              0.0
# routing_layer2_pct                             0.87
# routing_layer3_pct                              1.3
# routing_layer4_pct                              0.0
# routing_layer5_pct                              0.0
# routing_layer6_pct                              0.0
# wires_count                                       2
# wire_bits                                         2
# public_wires_count                                2
# public_wire_bits                                  2
# memories_count                                    0
# memory_bits                                       0
# processes_count                                   0
# cells_pre_abc                                     1
# AND                                               0
# DFF                                               0
# NAND                                              0
# NOR                                               0
# OR                                                0
# XOR                                               0
# XNOR                                              0
# MUX                                               0
# inputs                                            1
# outputs                                           1
# level                                             1
# EndCaps                                          20
# TapCells                                         12
# Diodes                                            0
# Total_Physical_Cells                             32
# CoreArea_um^2                              1051.008
# power_slowest_internal_uW                       0.0
# power_slowest_switching_uW                 0.000001
# power_slowest_leakage_uW                        0.0
# power_typical_internal_uW                       0.0
# power_typical_switching_uW                 0.000001
# power_typical_leakage_uW                        0.0
# power_fastest_internal_uW                       0.0
# power_fastest_switching_uW                 0.000001
# power_fastest_leakage_uW                        0.0
# critical_path_ns                               0.66
# suggested_clock_period                         11.0
# suggested_clock_frequency                 90.909091
# CLOCK_PERIOD                                   10.0
# SYNTH_STRATEGY                               AREA 0
# SYNTH_MAX_FANOUT                                 10
# FP_CORE_UTIL                                     50
# FP_ASPECT_RATIO                                   1
# FP_PDN_VPITCH                                  9.66
# FP_PDN_HPITCH                                 6.795
# PL_TARGET_DENSITY                               0.8
# GRT_ADJUSTMENT                                  0.3
# STD_CELL_LIBRARY                    sky130_fd_sc_hd
# DIODE_INSERTION_STRATEGY                          3
